# %% [markdown]
# # CSE-221710309053-Hari Sarmishta

# %% [markdown]
# ## Question 1:
# ### Print ManOfMach count of each player in Hyderabad stadium

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Match (1).csv")
df
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %%
city = df.loc[df.City_Name.eq("Hyderabad")]
players = city.groupby(['ManOfMach']) 

manOfmatch = players['ManOfMach'].count()

data = {'no of man of matches':manOfmatch} 
df1 = pd.DataFrame(data)
df1
# Out:
#                    no of man of matches
# ManOfMach
# A Mishra                              2
# AB Dinda                              1
# AT Rayudu                             1
# B Kumar                               1
# CH Morris                             1
# DA Warner                             6
# DJ Bravo                              1
# DJG Sammy                             1
# DW Steyn                              3
# G Gambhir                             1
# GH Vihari                             2
# I Sharma                              1
# MJ McClenaghan                        1
# MR Marsh                              1
# Mandeep Singh                         1
# Mustafizur Rahman                     1
# PA Patel                              1
# PC Valthaty                           1
# R Vinay Kumar                         1
# SC Ganguly                            1
# SE Marsh                              1
# SK Raina                              2
# ...

# %% [markdown]
# ## Question 2:
# ### Plot a pie chart for the country_name column

# %%
import matplotlib.pyplot as plt
country_data = df.Country_Name.unique()
sizes = df.groupby(['Country_Name']).count()


colors = ['blue', 'green', 'red']
explode = (0.1, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes.Match_SK,explode=explode, labels=country_data, colors=colors, autopct='%1.1f%%', shadow=True, startangle=45)

plt.axis('equal')
plt.show()
