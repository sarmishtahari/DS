# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img=plt.imread("color.jpg")
print(img.shape)# (height ,width,channels)
# Out:
# (168, 300, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,0])

# %%
plt.imshow(img[:,:,0],cmap='gray')

# %%
plt.imshow(img[:,:125,:])

# %%
plt.imshow(img[20:60,35:110,:])

# %%
plt.imshow(img[10:50,35:120,0])
